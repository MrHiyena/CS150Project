# %%
import pyttsx3
import pyttsx3.voice
import speech_recognition as sr
import openai
# import json

openai.api_key = "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"

# Source: https://github.com/andyblarblar/ros2_tts
class Text_To_Speech():
    def __init__(self):
        self.engine = pyttsx3.init()
        self.engine.setProperty('voice', '1')
        self.engine.setProperty('rate', 110)
        
    def speak(self, text):
        self.engine.say(text)
        self.engine.runAndWait()
        
    def store_voice(self,text):
        self.engine.save_to_file(text, 'text.mp4')
        self.engine.runAndWait()

# voices = test.engine.getProperty('voices')
# for voice in voices:
#     test.engine.setProperty('voice',voice.id)
#     test.store_voice("This is a test")

# Source: https://www.geeksforgeeks.org/python-convert-speech-to-text-and-text-to-speech/#
recog = sr.Recognizer()

try:
    with sr.Microphone() as source:
        recog.adjust_for_ambient_noise(source, duration = 0.2)
        
        audio = recog.listen(source, phrase_time_limit=5)
        
        text = recog.recognize_google(audio)
        text = text.lower()
        
        # Source: https://platform.openai.com/docs/guides/gpt/chat-completions-api
        # response = openai.Completion.create(
        #     model="gpt-3.5-turbo",
        #     prompt = text
        # )
        
        print("Did you say ", text)
        test = Text_To_Speech()
        test.speak(text)
except sr.RequestError as e:
    print("Could not request results; {0}".format(e))
except sr.UnknownValueError:
    print("unknown error occurred")
# Out:
# Did you say  hello my name is sohaib yes

# %%
import openai as ai
from openai import OpenAI

# Set your API key
api_k = "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"
client = OpenAI(api_key=api_k)

# Initialize the OpenAI API client
# https://platform.openai.com/docs/guides/text-generation
def ask_chatgpt(question):
    # Define the input prompt for ChatGPT
    prompt = question

    # Make a request to the API
    response = client.chat.completions.create(
        model ="gpt-3.5-turbo",
        messages= [
                {"role": "user", "content": prompt }
        ],
            
        # max_tokens=50,  # Adjust the desired response length
        # stop="\n",  # Stop when the model generates a newline character
    )

    # Extract and return the model's reply
    # reply = response.choices[0].text.strip()
    reply = str(response.choices[0].message.content)
    return reply

# Example usage
question = "What is the capital of France?"
reply = ask_chatgpt(question)
print("ChatGPT Response:"+ reply)

# %%
import openai
import pyttsx3
import speech_recognition as sr

# Source: https://platform.openai.com/docs/guides/text-generation
# Set your API key
api_k = "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"
openai.api_key = api_k

# Source: https://www.geeksforgeeks.org/python-convert-speech-to-text-and-text-to-speech/#
def get_user_command():
    recog = sr.Recognizer()
    try:
        with sr.Microphone() as source:
            recog.adjust_for_ambient_noise(source, duration = 0.2)
            
            audio = recog.listen(source, phrase_time_limit=5)
            
            text = recog.recognize_google(audio)
            text = text.lower()
            
            print("Did you say ", text)
    except sr.RequestError as e:
        print("Could not request results; {0}".format(e))
    except sr.UnknownValueError:
        print("unknown error occurred")
        
    return text

# Source: https://platform.openai.com/docs/guides/text-generation
def ask_chatgpt(text):
    # Define the input prompt for ChatGPT
    prompt = text

    # Make a request to the API
    response = openai.chat.completions.create(
        model ="gpt-3.5-turbo",
        messages= [
                {"role": "user", "content": prompt }
        ],
    )

    # Extract and return the model's reply
    reply = str(response.choices[0].message.content)
    return reply

# Our own code
question = get_user_command()
reply = ask_chatgpt(question)

# Source: https://github.com/andyblarblar/ros2_tts
class Text_To_Speech():
    def __init__(self):
        self.engine = pyttsx3.init()
        self.engine.setProperty('voice', '1')
        self.engine.setProperty('rate', 120)
        
    def speak(self, text):
        self.engine.say(text)
        self.engine.runAndWait()
        
    def store_voice(self,text):
        self.engine.save_to_file(text, 'text.mp4')
        self.engine.runAndWait()


test = Text_To_Speech()
test.speak(reply)
# Out:
# Did you say  who is the current president of the united states
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\mario\Desktop\CIS 150\Final_Project\tts.ipynb Cell 3 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/mario/Desktop/CIS%20150/Final_Project/tts.ipynb#W2sZmlsZQ%3D%3D?line=63'>64</a>         self.engine.runAndWait()
#      <a href='vscode-notebook-cell:/c%3A/Users/mario/Desktop/CIS%20150/Final_Project/tts.ipynb#W2sZmlsZQ%3D%3D?line=66'>67</a> test = Text_To_Speech()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/mario/Desktop/CIS%20150/Final_Project/tts.ipynb#W2sZmlsZQ%3D%3D?line=67'>68</a> test.speak(reply)
#
# c:\Users\mario\Desktop\CIS 150\Final_Project\tts.ipynb Cell 3 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/mario/Desktop/CIS%20150/Final_Project/tts.ipynb#W2sZmlsZQ%3D%3D?line=57'>58</a> def speak(self, text):
#      <a href='vscode-notebook-cell:/c%3A/Users/mario/Desktop/CIS%20150/Final_Project/tts.ipynb#W2sZmlsZQ%3D%3D?line=58'>59</a>     self.engine.say(text)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/mario/Desktop/CIS%20150/Final_Project/tts.ipynb#W2sZmlsZQ%3D%3D?line=59'>60</a>     self.engine.runAndWait()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyttsx3\engine.py:180, in Engine.runAndWait(self)
#     178 self._inLoop = True
#     179 self._driverLoop = True
# --> 180 self.proxy.runAndWait()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyttsx3\driver.py:192, in DriverProxy.runAndWait(self)
#     187 '''
#     188 Called by the engine to start an event loop, process all commands in
#     189 the queue at the start of the loop, and then exit the loop.
#     190 '''
#     191 self._push(self._engine.endLoop, tuple())
# --> 192 self._driver.startLoop()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyttsx3\drivers\sapi5.py:128, in SAPI5Driver.startLoop(self)
#     126     first = False
#     127 pythoncom.PumpWaitingMessages()
# --> 128 time.sleep(0.05)
#
# KeyboardInterrupt:
